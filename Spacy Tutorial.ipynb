# %% [markdown]
# # Importing our Library

# %%
import spacy

# %% [markdown]
# ### 'en_core_web_sm' is a english Lib
# ##### visit : https://spacy.io/usage/models
# ##### for documentation

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp("Cpt. america ate 100$ of samosa. Then he said I can do this all day.")

# %%
doc
# Out:
# Cpt. america ate 100$ of samosa. Then he said I can do this all day.

# %%
# Its identifing the sentences

# %%
for sentence in doc.sents:
    print(sentence)
# Out:
# Cpt. america ate 100$ of samosa.
# Then he said I can do this all day.

# %%
for sentence in doc.sents:
    for word in sentence:
        print(word)
# Out:
# Cpt
# .
# america
# ate
# 100
# $
# of
# samosa
# .
# Then
# he
# said
# I
# can
# do
# this
# all
# day
# .

# %%
import nltk
# We get above error because we have a blank pipeline as shown below. Pipeline is something that starts with a Tokenizer component in a dotted rectange below. You can see there is nothing there hence the blank pipeline

# %%
#nltk.download('punkt')

# %%
from nltk.tokenize import sent_tokenize
sent_tokenize("Cpt. america ate 100$ of samosa. Then he said I can do this all day.")
# Out:
# ['Cpt.', 'america ate 100$ of samosa.', 'Then he said I can do this all day.']

# %%
from nltk.tokenize import word_tokenize
word_tokenize("Cpt. america ate 100$ of samosa. Then he said I can do this all day.")
# Out:
# ['Cpt',
#  '.',
#  'america',
#  'ate',
#  '100',
#  '$',
#  'of',
#  'samosa',
#  '.',
#  'Then',
#  'he',
#  'said',
#  'I',
#  'can',
#  'do',
#  'this',
#  'all',
#  'day',
#  '.']

# %% [raw]
# Creating a blank pipeline

# %%
nlp = spacy.blank('en')

# %%
doc = nlp("Captain america ate 100$ of samosa. Then he said I can$ do this all day.")

# %%
for token in doc:
    print(token)
# Out:
# Captain
# america
# ate
# 100
# $
# of
# samosa
# .
# Then
# he
# said
# I
# can$
# do
# this
# all
# day
# .

# %%
doc = nlp("Tony gave two $ to Peter,")

# %%
token0=doc[0]
token0
# Out:
# Tony

# %%
dir(token0)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
# ...

# %%
type(token0)
# Out:
# spacy.tokens.token.Token

# %% [markdown]
# ### Understanding the Types of tokens

# %%
token.is_alpha
# Out:
# False

# %%
token.like_num
# Out:
# False

# %%
token2=doc[2]
token2.text
# Out:
# 'two'

# %%
token3=doc[3]
token3.is_currency
# Out:
# True

# %%
for token in doc:
    print(token, "==>","index",token.i,"is_alpha",token.is_alpha,
         "is_punc",token.is_punct,
         "like_num",token.like_num,
         "is_currency:",token.is_currency)
# Out:
# Tony ==> index 0 is_alpha True is_punc False like_num False is_currency: False
# gave ==> index 1 is_alpha True is_punc False like_num False is_currency: False
# two ==> index 2 is_alpha True is_punc False like_num True is_currency: False
# $ ==> index 3 is_alpha False is_punc False like_num False is_currency: True
# to ==> index 4 is_alpha True is_punc False like_num False is_currency: False
# Peter ==> index 5 is_alpha True is_punc False like_num False is_currency: False
# , ==> index 6 is_alpha False is_punc True like_num False is_currency: False

# %%
import pandas as pd

# %%
with open("students.txt") as f:
    text=f.readlines()
text
# Out:
# ['Dayton high school, 8th grade students information\n',
#  '==================================================\n',
#  '\n',
#  'Name\tbirth day   \temail\n',
#  '-----\t------------\t------\n',
#  'Virat   5 June, 1882    virat@kohli.com\n',
#  'Maria\t12 April, 2001  maria@sharapova.com\n',
#  'Serena  24 June, 1998   serena@williams.com \n',
#  'Joe      1 May, 1997    joe@root.com\n',
#  '\n',
#  '\n',
#  '\n']

# %%
text = " ".join(text)
text
# Out:
# 'Dayton high school, 8th grade students information\n ==================================================\n \n Name\tbirth day   \temail\n -----\t------------\t------\n Virat   5 June, 1882    virat@kohli.com\n Maria\t12 April, 2001  maria@sharapova.com\n Serena  24 June, 1998   serena@williams.com \n Joe      1 May, 1997    joe@root.com\n \n \n \n'

# %%
doc = nlp(text)
email =[]
for token in doc:
    if token.like_email:
        email.append(token.text)
email
# Out:
# ['virat@kohli.com',
#  'maria@sharapova.com',
#  'serena@williams.com',
#  'joe@root.com']

# %%
nlp = spacy.blank("hi")
doc = nlp("भैया जी! 5000 ₹ उधार थे वो वापस देदो")
for token in doc:
    print(token,token.is_currency,token.like_num)
# Out:
# भैया False False
# जी False False
# ! False False
# 5000 False True
# ₹ True False
# उधार False False
# थे False False
# वो False False
# वापस False False
# देदो False False

# %%
doc = nlp("gimme double cheese extra large healthy pizza")

tokens = [token.text for token in doc]
tokens
# Out:
# ['gimme', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %% [markdown]
# ### Adding special rule
# but it will not be able to create new text , it is a little dumb and can only split the text

# %%
from spacy.symbols import ORTH
nlp.tokenizer.add_special_case("gimme",[{ORTH : "gim"},{ORTH : "me"}])
doc = nlp("gimme double cheese extra large healthy pizza")

tokens = [token.text for token in doc]
tokens
# Out:
# ['gim', 'me', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
for sentence in doc.sents:
    print(sentence)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
# ----> 2 for sentence in doc.sents:
#       3     print(sentence)
#
# File ~\anaconda3\Lib\site-packages\spacy\tokens\doc.pyx:923, in sents()
#
# ValueError: [E030] Sentence boundaries unset. You can add the 'sentencizer' component to the pipeline with: `nlp.add_pipe('sentencizer')`. Alternatively, add the dependency parser or sentence recognizer, or set sentence boundaries by setting `doc[i].is_sent_start`.

# %% [markdown]
# ##### sentencizer needs to be added to the pipeline

# %%
nlp.add_pipe('sentencizer')

# %%
nlp.pipe_names
# Out:
# ['sentencizer']

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
for sentence in doc.sents:
    print(sentence)
# Out:
# Dr.
# Strange loves pav bhaji of mumbai.
# Hulk loves chat of delhi

# %% [markdown]
# #### A Small Excercise to extract the website links from the text

# %%
text='''
Look for data to help you address the question. Governments are good
sources because data from public research is often freely available. Good
places to start include http://www.data.gov/, and http://www.science.
gov/, and in the United Kingdom, http://data.gov.uk/.
Two of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/, 
and the European Social Survey at http://www.europeansocialsurvey.org/.
'''

# TODO: Write code here
# Hint: token has an attribute that can be used to detect a url

# %%
doc = nlp(text)

# %%
doc
# Out:
# Look for data to help you address the question. Governments are good
# sources because data from public research is often freely available. Good
# places to start include http://www.data.gov/, and http://www.science.
# gov/, and in the United Kingdom, http://data.gov.uk/.
# Two of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/,
# and the European Social Survey at http://www.europeansocialsurvey.org/.

# %%
emails = [token.text for token in doc if token.like_url ]
emails
# Out:
# ['http://www.data.gov/',
#  'http://www.science',
#  'http://data.gov.uk/.',
#  'http://www3.norc.org/gss+website/',
#  'http://www.europeansocialsurvey.org/.']

# %% [markdown]
# #### Excercise 2
# #### Extract all money transaction from below sentence along with currency. Output should be,
#
# two $
#
# 500 €

# %%
transactions = "Tony gave two $ to Peter, Bruce gave 500 € to Steve"

# TODO: Write code here
# Hint: Use token.i for the index of a token and token.is_currency for currency symbol detection

# %%
doc = nlp(transactions)

# %%
for token in doc:
    if doc[token.i].is_currency:
        print(doc[token.i-1].text,token)
# Out:
# two $
# 500 €

# %%
nlp= spacy.blank("en")

# %%
doc = nlp("Cpt. america ate 100$ of samosa. Then he said I can do this all day.")

# %%
for token in doc:
    print(token)
# Out:
# Cpt
# .
# america
# ate
# 100
# $
# of
# samosa
# .
# Then
# he
# said
# I
# can
# do
# this
# all
# day
# .

# %%
nlp.pipe_names
# Out:
# []

# %% [markdown]
# ## Blank pipelines have nothing in them ,
# ### they are just tokens , once u download a pipeline like below u will have multiple things like
# ### tagger , parse , ner

# %%
nlp= spacy.load("en_core_web_sm")

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x10f38ff7590>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x10f317635f0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x10f39184ac0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x10f394272d0>),
#  ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x10f39435450>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x10f39184b30>)]

# %%
#now lets find out what these pipelines are

# %%
doc = nlp("Cpt. america ate 100$ of samosa. Then he said I can do this all day.")

for token in doc:
    print(token," | ",token.pos_," | ",token.lemma_)
# Out:
# Cpt  |  PROPN  |  Cpt
# .  |  PROPN  |  .
# america  |  PROPN  |  america
# ate  |  VERB  |  eat
# 100  |  NUM  |  100
# $  |  NUM  |  $
# of  |  ADP  |  of
# samosa  |  PROPN  |  samosa
# .  |  PUNCT  |  .
# Then  |  ADV  |  then
# he  |  PRON  |  he
# said  |  VERB  |  say
# I  |  PRON  |  I
# can  |  AUX  |  can
# do  |  VERB  |  do
# this  |  PRON  |  this
# all  |  DET  |  all
# day  |  NOUN  |  day
# .  |  PUNCT  |  .

# %%
doc = nlp("Tesla Inc is going to acquire twitter for $45 billion")
for ent in doc.ents:
    print(ent.text," | " ,ent.label_," | ",spacy.explain(ent.label_))
# Out:
# Tesla Inc  |  ORG  |  Companies, agencies, institutions, etc.
# $45 billion  |  MONEY  |  Monetary values, including unit

# %%
from spacy import displacy

# %%
displacy.render(doc,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is going to acquire twitter for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $45 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %% [markdown]
# # Importing the French lib. copy code form spacy official website

# %%
nlp = spacy.load("fr_core_news_sm")

# %%
doc = nlp("Tesla Inc va racheter Twitter pour $45 milliards de dollars")
for ent in doc.ents:
    print(ent.text, " | ", ent.label_, " | ", spacy.explain(ent.label_))
# Out:
# Tesla Inc  |  ORG  |  Companies, agencies, institutions, etc.
# Twitter  |  MISC  |  Miscellaneous entities, e.g. events, nationalities, products or works of art

# %%
displacy.render(doc,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  va racheter
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  pour $45 milliards de dollars</div></span>

# %%
for token in doc:
    print(token, " | ", token.pos_, " | ", token.lemma_)
# Out:
# Tesla  |  PROPN  |  Tesla
# Inc  |  PROPN  |  Inc
# va  |  VERB  |  aller
# racheter  |  VERB  |  racheter
# Twitter  |  VERB  |  twitter
# pour  |  ADP  |  pour
# $  |  NOUN  |  dollar
# 45  |  NUM  |  45
# milliards  |  NOUN  |  milliard
# de  |  ADP  |  de
# dollars  |  NOUN  |  dollar

# %% [markdown]
# ### Adding NER from english lib. to blank

# %%
source_nlp = spacy.load("en_core_web_sm")

nlp = spacy.blank("en")
nlp.add_pipe("ner", source=source_nlp)
nlp.pipe_names
# Out:
# ['ner']

# %%
doc = nlp("Tesla Inc is going to acquire twitter for $45 billion")
for ent in doc.ents:
    print(ent.text," | " ,ent.label_," | ",spacy.explain(ent.label_))
# Out:
# Tesla Inc  |  ORG  |  Companies, agencies, institutions, etc.
# $45 billion  |  MONEY  |  Monetary values, including unit

# %% [markdown]
# # Stemming & Lemmatization

# %% [markdown]
# ![20240512_154510000_iOS.jpg](attachment:cfc7c16d-b3fe-440b-8d97-1cb70c7c5d32.jpg)r>
# </table>

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc= nlp("Elon flew to mars yesterday. He carried biryani masala with him")

# %% [markdown]
# #### Identification of Part Of Speech

# %% [markdown]
# #### components to identify POS as we are using a trained model

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
for token in doc:
    print(token," | ",token.pos_ ," | ",spacy.explain(token.pos_))
# Out:
# Elon  |  PROPN  |  proper noun
# flew  |  VERB  |  verb
# to  |  ADP  |  adposition
# mars  |  NOUN  |  noun
# yesterday  |  NOUN  |  noun
# .  |  PUNCT  |  punctuation
# He  |  PRON  |  pronoun
# carried  |  VERB  |  verb
# biryani  |  ADJ  |  adjective
# masala  |  NOUN  |  noun
# with  |  ADP  |  adposition
# him  |  PRON  |  pronoun

# %%
doc = nlp("Wow! Dr. Strange made 265 million $ on the very first day")

for token in doc:
    print(token," | ", token.pos_, " | ", spacy.explain(token.pos_)," | ",token.tag_," | " ,spacy.explain(token.tag_) )
# Out:
# Wow  |  INTJ  |  interjection  |  UH  |  interjection
# !  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# Dr.  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Strange  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# made  |  VERB  |  verb  |  VBD  |  verb, past tense
# 265  |  NUM  |  numeral  |  CD  |  cardinal number
# million  |  NUM  |  numeral  |  CD  |  cardinal number
# $  |  NUM  |  numeral  |  CD  |  cardinal number
# on  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# very  |  ADV  |  adverb  |  RB  |  adverb
# first  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# day  |  NOUN  |  noun  |  NN  |  noun, singular or mass

# %%
doc = nlp("He quits the job")
doc[1]
print(doc[1].text,"|",doc[1].tag_,"|",spacy.explain(doc[1].tag_))
# Out:
# quits | VBZ | verb, 3rd person singular present

# %%
doc = nlp("He quit the job")
doc[1]
print(doc[1].text,"|",doc[1].tag_,"|",spacy.explain(doc[1].tag_))
# Out:
# quit | VBD | verb, past tense

# %%
# spacy is smart enouth that it can identify the tense it is being used in

# %%
earnings_text="""Microsoft Corp. today announced the following results for the quarter ended December 31, 2021, as compared to the corresponding period of last fiscal year:

·         Revenue was $51.7 billion and increased 20%
·         Operating income was $22.2 billion and increased 24%
·         Net income was $18.8 billion and increased 21%
·         Diluted earnings per share was $2.48 and increased 22%
“Digital technology is the most malleable resource at the world’s disposal to overcome constraints and reimagine everyday work and life,” said Satya Nadella, chairman and chief executive officer of Microsoft. “As tech as a percentage of global GDP continues to increase, we are innovating and investing across diverse and growing markets, with a common underlying technology stack and an operating model that reinforces a common strategy, culture, and sense of purpose.”
“Solid commercial execution, represented by strong bookings growth driven by long-term Azure commitments, increased Microsoft Cloud revenue to $22.1 billion, up 32% year over year” said Amy Hood, executive vice president and chief financial officer of Microsoft."""

# %%
doc = nlp(earnings_text)


for token in doc:
    print(token," | ", token.pos_, " | ", spacy.explain(token.pos_)," | ",token.tag_," | " ,spacy.explain(token.tag_) )
# Out:
# Microsoft  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Corp.  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# today  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# announced  |  VERB  |  verb  |  VBD  |  verb, past tense
# the  |  DET  |  determiner  |  DT  |  determiner
# following  |  VERB  |  verb  |  VBG  |  verb, gerund or present participle
# results  |  NOUN  |  noun  |  NNS  |  noun, plural
# for  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# quarter  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# ended  |  VERB  |  verb  |  VBD  |  verb, past tense
# December  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# 31  |  NUM  |  numeral  |  CD  |  cardinal number
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# 2021  |  NUM  |  numeral  |  CD  |  cardinal number
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# ...

# %% [markdown]
# #### We need to remove these extra characters

# %%
filtered_tokens = []
for token in doc:
    if token.pos_ not in ["SPACE", "PUNCT", "X"]:
        filtered_tokens.append(token)

# %%
for token in filtered_tokens:
    print(token," | ", token.pos_, " | ", spacy.explain(token.pos_)," | ",token.tag_," | " ,spacy.explain(token.tag_) )
# Out:
# Microsoft  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Corp.  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# today  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# announced  |  VERB  |  verb  |  VBD  |  verb, past tense
# the  |  DET  |  determiner  |  DT  |  determiner
# following  |  VERB  |  verb  |  VBG  |  verb, gerund or present participle
# results  |  NOUN  |  noun  |  NNS  |  noun, plural
# for  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# quarter  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# ended  |  VERB  |  verb  |  VBD  |  verb, past tense
# December  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# 31  |  NUM  |  numeral  |  CD  |  cardinal number
# 2021  |  NUM  |  numeral  |  CD  |  cardinal number
# as  |  SCONJ  |  subordinating conjunction  |  IN  |  conjunction, subordinating or preposition
# ...

# %%
count = doc.count_by(spacy.attrs.POS)
count
# Out:
# {96: 13,
#  92: 46,
#  100: 24,
#  90: 9,
#  85: 16,
#  93: 16,
#  97: 27,
#  98: 1,
#  84: 20,
#  103: 10,
#  87: 6,
#  99: 5,
#  89: 12,
#  86: 3,
#  94: 3,
#  95: 2}

# %%
doc.vocab[96].text
# Out:
# 'PROPN'

# %%
for k,v in count.items():
    print(doc.vocab[k].text, " | ",v)
# Out:
# PROPN  |  13
# NOUN  |  46
# VERB  |  24
# DET  |  9
# ADP  |  16
# NUM  |  16
# PUNCT  |  27
# SCONJ  |  1
# ADJ  |  20
# SPACE  |  10
# AUX  |  6
# SYM  |  5
# CCONJ  |  12
# ADV  |  3
# PART  |  3
# PRON  |  2

# %% [markdown]
# ### A small excercise to practice what we have done till now
#
# 1 Extract all NOUN tokens from this story.
# 2 :
# Extract all numbers (NUM POS type) in a python ist.
# t 3 :
# Print a count of all POS tags in this story

# %%
Text = "Inflation rose again in April, continuing a climb that has pushed consumers to the brink and is threatening the economic expansion, the Bureau of Labor Statistics reported Wednesday.The consumer price index, a broad-based measure of prices for goods and services, increased 8.3% from a year ago, higher than the Dow Jones estimate for an 8.1% gain. That represented a slight ease from March’s peak but was still close to the highest level since the summer of 1982.Removing volatile food and energy prices, so-called core CPI still rose 6.2%, against expectations for a 6% gain, clouding hopes that inflation had peaked in March.The month-over-month gains also were higher than expectations — 0.3% on headline CPI versus the 0.2% estimate and a 0.6% increase for core, against the outlook for a 0.4% gain.The price gains also meant that workers continued to lose ground. Real wages adjusted for inflation decreased 0.1% on the month despite a nominal increase of 0.3% in average hourly earnings. Over the past year, real earnings have dropped 2.6% even though average hourly earnings are up 5.5%.Inflation has been the single biggest threat to a recovery that began early in the Covid pandemic and saw the economy in 2021 stage its biggest single-year growth level since 1984. Rising prices at the pump and in grocery stores have been one problem, but inflation has spread beyond those two areas into housing, auto sales and a host of other areas.Federal Reserve officials have responded to the problem with two interest rate hikes so far this year and pledges of more until inflation comes down to the central bank’s 2% goal. However, Wednesday’s data shows that the Fed has a big job ahead.Credits: cnbc.com"

# %%
doc = nlp(Text)

# %%
filtered_noun=[]
numeral_tokens=[]
for token in doc:
    if token.pos_ in ["NOUN"]:
        filtered_noun.append(token)
    elif token.pos_ == 'NUM':
        numeral_tokens.append(token)

# %%
for token in filtered_noun:
    print(token," | ", token.pos_, " | ", spacy.explain(token.pos_)," | ",token.tag_," | " ,spacy.explain(token.tag_) )
# Out:
# Inflation  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# climb  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# consumers  |  NOUN  |  noun  |  NNS  |  noun, plural
# brink  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# expansion  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# consumer  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# price  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# index  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# measure  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# prices  |  NOUN  |  noun  |  NNS  |  noun, plural
# goods  |  NOUN  |  noun  |  NNS  |  noun, plural
# services  |  NOUN  |  noun  |  NNS  |  noun, plural
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# year  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# estimate  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# gain  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# ...

# %%
filtered_noun[1].pos_
# Out:
# 'NOUN'

# %%
numeral_tokens[1].pos_
# Out:
# 'NUM'

# %%
count = doc.count_by(spacy.attrs.POS)
count
# Out:
# {92: 94,
#  100: 27,
#  86: 15,
#  85: 39,
#  96: 16,
#  97: 30,
#  90: 34,
#  95: 4,
#  87: 13,
#  89: 10,
#  84: 23,
#  93: 18,
#  94: 4,
#  98: 8,
#  101: 1}

# %%
for k,v in count.items():
    print(doc.vocab[k].text, " | ",v)
# Out:
# NOUN  |  94
# VERB  |  27
# ADV  |  15
# ADP  |  39
# PROPN  |  16
# PUNCT  |  30
# DET  |  34
# PRON  |  4
# AUX  |  13
# CCONJ  |  10
# ADJ  |  23
# NUM  |  18
# PART  |  4
# SCONJ  |  8
# X  |  1

# %% [markdown]
# # Named Entity Recognition (NER)

# %%
nlp = spacy.load("en_core_web_sm")
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc = nlp("Tesla Inc is going to acquire twitter for $45 billion")
for ent in doc.ents: # Ents will find entities from the text 
    print(ent.text, " | ", ent.label_, " | ", spacy.explain(ent.label_))
# Out:
# Tesla Inc  |  ORG  |  Companies, agencies, institutions, etc.
# $45 billion  |  MONEY  |  Monetary values, including unit

# %%
from spacy import displacy

displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is going to acquire twitter for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $45 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
nlp.pipe_labels['ner']
# Out:
# ['CARDINAL',
#  'DATE',
#  'EVENT',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LAW',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERCENT',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART']

# %%
doc = nlp("Michael Bloomberg founded Bloomberg in 1982")
for ent in doc.ents:
    print(ent.text, "|", ent.label_, "|", spacy.explain(ent.label_))
# Out:
# Michael Bloomberg | PERSON | People, including fictional
# Bloomberg | PERSON | People, including fictional
# 1982 | DATE | Absolute or relative dates or periods

# %%
 from spacy import displacy

displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  founded
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1982
# ...

# %%
doc = nlp("Tesla Inc is going to acquire Twitter Inc for $45 billion")
for ent in doc.ents:
    print(ent.text, " | ", ent.label_, " | ", ent.start_char, "|", ent.end_char)
# Out:
# Tesla Inc  |  ORG  |  0 | 9
# Twitter Inc  |  ORG  |  30 | 41
# $45 billion  |  MONEY  |  46 | 57

# %%
doc = nlp("Tesla is going acquired Twitter for $45 billion")
for ent in doc.ents:
    print(ent.text,"|",ent.label_)
# Out:
# Tesla | ORG
# Twitter | PRODUCT
# $45 billion | MONEY

# %%
type(doc[2:4])
# Out:
# spacy.tokens.span.Span

# %%
from spacy.tokens import Span

# %%
s1 = Span(doc,0,1,label="ORG")
s2 = Span(doc,4,5,label="ORG")

doc.set_ents([s1,s2],default="unmodified")

# %%
for ent in doc.ents:
    print(ent.text,"|",ent.label_)
# Out:
# Tesla | ORG
# Twitter | ORG
# $45 billion | MONEY

# %%
#Sample text
text = "This is a sample number (555) 555-5555."

#Build upon the spaCy Small Model
nlp = spacy.blank("en")

#Create the Ruler and Add it
ruler = nlp.add_pipe("entity_ruler")

#List of Entities and Patterns (source: https://spacy.io/usage/rule-based-matching)
patterns = [
                {"label": "PHONE_NUMBER", "pattern": [{"ORTH": "("}, {"SHAPE": "ddd"}, {"ORTH": ")"}, {"SHAPE": "ddd"},
                {"ORTH": "-", "OP": "?"}, {"SHAPE": "dddd"}]}
            ]
#add patterns to ruler
ruler.add_patterns(patterns)



#create the doc
doc = nlp(text)

#extract entities
for ent in doc.ents:
    print (ent.text, ent.label_,)
# Out:
# (555) 555-5555 PHONE_NUMBER
